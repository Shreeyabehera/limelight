# %% [markdown]
# # Forecasting Gross Broadway Sales using Facebook Prophet
#
# Our goal in this notebook is to use Facebook Prophet to build a model that will predict the gross sales for a particular theater; in this case, Gershwin Theater.
#
# ## Setup
#
# Let us first import the packages we need.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from prophet import Prophet

sns.set_style("whitegrid")

# %% [markdown]
# Next, we read in the data file `grosses.csv`.

# %%
df_raw = pd.read_csv('../DATA-COLLECTION/grosses.csv')
df_raw.head()
# Out:
#   week_ending  week_number  weekly_gross_overall              show  \
# 0  1985-06-09            1             3915937.0       42nd Street
# 1  1985-06-09            1             3915937.0     A Chorus Line
# 2  1985-06-09            1             3915937.0    Aren't We All?
# 3  1985-06-09            1             3915937.0  Arms and the Man
# 4  1985-06-09            1             3915937.0             As Is
#
#                         theatre  weekly_gross  potential_gross  \
# 0             St. James Theatre      282368.0              NaN
# 1        Sam S. Shubert Theatre      222584.0              NaN
# 2       Brooks Atkinson Theatre      249272.0              NaN
# 3  Circle in the Square Theatre       95688.0              NaN
# 4                Lyceum Theatre       61059.0              NaN
#
#    avg_ticket_price  top_ticket_price  seats_sold  seats_in_theatre  \
# 0             30.42               NaN        9281              1655
# 1             27.25               NaN        8167              1472
# 2             33.75               NaN        7386              1088
# 3             20.87               NaN        4586               682
# 4             20.78               NaN        2938               684
#
#    pct_capacity  performances  previews
# 0        0.7010             8         0
# 1        0.6935             8         0
# 2        0.8486             8         0
# 3        0.8405             8         0
# 4        0.5369             8         0

# %% [markdown]
# Next, we perform a bit of exploration to see if there's anything odd about the data.

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47524 entries, 0 to 47523
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   week_ending           47524 non-null  object
#  1   week_number           47524 non-null  int64
#  2   weekly_gross_overall  47524 non-null  float64
#  3   show                  47524 non-null  object
#  4   theatre               47524 non-null  object
#  5   weekly_gross          47524 non-null  float64
#  6   potential_gross       34911 non-null  float64
#  7   avg_ticket_price      47524 non-null  float64
#  8   top_ticket_price      36167 non-null  float64
#  9   seats_sold            47524 non-null  int64
#  10  seats_in_theatre      47524 non-null  int64
#  11  pct_capacity          47524 non-null  float64
#  12  performances          47524 non-null  int64
#  13  previews              47524 non-null  int64
# dtypes: float64(6), int64(5), object(3)
# memory usage: 5.1+ MB

# %% [markdown]
# The columns we're interested in are `week_ending`, `theatre`, and `weekly_gross`. Happily, none of these columns have null values.
#
# Let's also get some simple stats to get an idea of the numbers we're working with.

# %%
df_raw.describe()
# Out:
#         week_number  weekly_gross_overall  weekly_gross  potential_gross  \
# count  47524.000000          4.752400e+04  4.752400e+04     3.491100e+04
# mean      27.372170          1.669303e+07  5.744868e+05     9.395982e+05
# std       15.310139          9.520198e+06  4.433470e+05     4.193233e+05
# min        1.000000          2.474396e+06  0.000000e+00     7.754000e+03
# 25%       14.000000          9.093031e+06  2.622292e+05     6.295230e+05
# 50%       28.000000          1.506067e+07  4.700645e+05     9.031500e+05
# 75%       41.000000          2.289759e+07  7.584381e+05     1.190502e+06
# max       53.000000          5.780727e+07  4.041493e+06     3.559306e+06
#
#        avg_ticket_price  top_ticket_price    seats_sold  seats_in_theatre  \
# count      47524.000000      36167.000000  47524.000000      47524.000000
# mean          67.914736        189.681892   7893.449668       1237.793536
# std           38.589416        112.304515   3186.019908        358.357398
# min            0.000000          4.000000      0.000000          0.000000
# 25%           43.370000         85.000000   5442.000000       1021.000000
# 50%           60.235000        200.000000   7736.000000       1181.000000
# 75%           84.652500        250.000000  10187.000000       1509.000000
# max          511.580000        998.000000  24305.000000       1969.000000
#
#        pct_capacity  performances      previews
# count  47524.000000  47524.000000  47524.000000
# mean       0.802753      7.237754      0.583663
# std        0.176418      2.229733      1.926202
# min        0.000000      0.000000      0.000000
# 25%        0.691400      8.000000      0.000000
# 50%        0.833000      8.000000      0.000000
# 75%        0.953800      8.000000      0.000000
# max        1.553600     17.000000     16.000000

# %% [markdown]
# ## Creating a DataFrame to feed to Prophet
#
# Prophet requires a two-column DataFrame to build a model; the first column must be in `datetime` format, and the second column must be numerical. We need to manipulate `df_raw` to get the weekly grosses of Gershwin theater, indexed by the ending week.
#
# First, let's extract all of the rows that have 'Gershwin Theater' in the `theatre` column.

# %%
df_gershwin = df_raw[df_raw['theatre'] == 'Gershwin Theatre']

# %% [markdown]
# Next, let's drop all columns except for `week_ending` and `weekly_gross` and reindex.

# %%
df_week_gross_series = df_gershwin[['week_ending', 'weekly_gross']].reset_index(drop = True)

# %% [markdown]
# And convert the `week_ending` column from string to `datetime` format.

# %%
df_week_gross_series['week_ending'] = pd.to_datetime(df_week_gross_series['week_ending'])

# %% [markdown]
# Also, Prophet has the requirement that the two columns must be titled 'ds' and 'y', so let's rename them.

# %%
df_week_gross_series = df_week_gross_series.rename(columns={'week_ending': 'ds', 'weekly_gross': 'y'})

# %% [markdown]
# Next, we extract all rows between the dates 2013-06-02 and 2018-05-27, and preview the final DataFrame.

# %%
from datetime import datetime

start_date = datetime.strptime('2013-06-02', '%Y-%m-%d')
end_date = datetime.strptime('2018-05-27', '%Y-%m-%d')

df_final = df_week_gross_series.loc[(df_week_gross_series.ds >= start_date) & (df_week_gross_series.ds <= end_date)]
df_final.head()
# Out:
#              ds          y
# 1174 2013-06-02  1776282.0
# 1175 2013-06-09  1770507.0
# 1176 2013-06-16  1849045.0
# 1177 2013-06-23  2041391.0
# 1178 2013-06-30  1985154.0

# %% [markdown]
# Let's plot the evolution of `y` over time, to see how it looks.

# %%
plt.figure(figsize=(16,8))
plt.plot(df_final['ds'], df_final['y'])

# %% [markdown]
# ## Building a model
#
# We call Prophet and fit it to our DataFrame `df_final`.

# %%
m = Prophet()
m.fit(df_final)
# Out:
# 01:29:05 - cmdstanpy - INFO - Chain [1] start processing
# 01:29:05 - cmdstanpy - INFO - Chain [1] done processing

# %% [markdown]
# Next, we fill out the date column with 52 weeks into the future.

# %%
future = m.make_future_dataframe(periods=52, freq = 'W')
future.tail()
# Out:
#             ds
# 307 2019-04-28
# 308 2019-05-05
# 309 2019-05-12
# 310 2019-05-19
# 311 2019-05-26

# %% [markdown]
# Then we call the `predict` method on `future`, to get predictions $\hat y$.

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#             ds          yhat    yhat_lower    yhat_upper
# 307 2019-04-28  1.793607e+06  1.522036e+06  2.051660e+06
# 308 2019-05-05  1.647684e+06  1.392580e+06  1.910157e+06
# 309 2019-05-12  1.620392e+06  1.382443e+06  1.876437e+06
# 310 2019-05-19  1.706667e+06  1.451888e+06  1.953987e+06
# 311 2019-05-26  1.816144e+06  1.567273e+06  2.093308e+06

# %% [markdown]
# Let's plot the predictions (blue curve) together with the actual data (black dots) to get an initial idea of how the model did.

# %%
fig1 = m.plot(forecast)

# %% [markdown]
# ## Diagnostics
#
# Next, we want to evaluate how well the model did.
